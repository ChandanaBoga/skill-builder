# %%
class Profile:
    def __init__(self,username):
        self.followers=0
        self.username=username
    def follow(self):
        print("someone is following you")
        self.followers+=1
    def update_username(self,nun):
        self.username=nun
p1=Profile("_mshr_ak_")
p1.follow()
print(p1.followers)
print(p1.username)
p1.update_username("mshu")
print(p1.username)
# Out:
# someone is following you
# 1
# _mshr_ak_
# mshu

# %%
class Building:
    no_of_rooms=0
    total_building=0
    def __init__(self,x,y):
        self.buildingName=x
        self.wifi=y
        Building.total_building+=1
B1=Building("Cvcorp",True)
print(B1.total_building)
print(B1.buildingName)

B2=Building("corp",True)
print(B2.total_building)

B3=Building("xyz",True)
print(B2.total_building)
print(B3.total_building)
# Out:
# 1
# Cvcorp
# 2
# 3
# 3

# %%
class  Person:
    total_Phone_number=10
    def __init__(self,Name,age,phone):
        self.Name=Name
        self.age=age
        self.phone=phone
        if phone == True:
            Person.total_Phone_number+=1
obj1=Person("ram",15,True)
obj2=Person("sita",16,True)
obj3=Person("ravi",14,False)
print(obj1.Name)
print(obj1.total_Phone_number)
print(obj2.total_Phone_number)
print(obj3.total_Phone_number)
print(obj3.phone)
# Out:
# ram
# 2
# 2
# 2
# False

# %%
class Building:
    no_of_rooms=10
    total_building=0
    def __init__(self,x,y):
        self.buildingName=x
        self.wifi=y
        Building.total_building+=1
    def change_rooms(self,newroom):
        self.no_of_rooms=newroom

B1=Building("Cvcorp",True)
print(B1.total_building)
print(B1.buildingName)

B2=Building("corp",True)
print(B2.total_building)

B3=Building("xyz",True)
print(B2.total_building)
print(B3.total_building)

B1.change_rooms("abc")
print(Building.no_of_rooms)
B1.change_rooms(20)
print(Building.no_of_rooms)
# Out:
# 1
# Cvcorp
# 2
# 3
# 3
# 10
# 10

# %%
class Building:
    total_rooms=10
    def __init__(self,name,roadno):
        self.name=name
        self.roadno=roadno
    @classmethod
    def change_rooms(cls,trooms):
        cls.total_rooms=trooms
b1=Building("mb",1)
b2=Building("pb",2)
print(b1.total_rooms)
print(b2.total_rooms)
b1.change_rooms(20)
print(b1.total_rooms)
print(b2.total_rooms)
Building.change_rooms(15)
print(b1.total_rooms)
print(b2.total_rooms)
# Out:
# 10
# 10
# 20
# 20
# 15
# 15

# %%
class A:
    x=20
    def __init__(self,a,b):
        self.x=a
        self.x=b
    def m1(self,k):
        self.x=k
    @classmethod
    def m2 (cls):
        cls.x=50
obj=A(30,40)
obj.m1(60)
print(obj.x)
print(A.x)
A.m2()
print(obj.x)
print(A.x)
# Out:
# 60
# 20
# 60
# 50

# %%
class A:
    def __init__(self,q,r):
        self.q=q
        self.r=r
    @classmethod
    def divideby10(cls,n):
        return cls(n//10,n%10)
obj=A.divideby10(25)
print(obj.q)
print(obj.r)
# Out:
# 2
# 5

# %%
class Student:
    batch=0
    def __init__(self,name,):
        self.name=name
    @classmethod
    def change_batch(cls):

# %%
# Q1. Create a class Student with instance attributes name and marks.
# Add an instance method is_passed() that returns True if marks > 40.
# Then create 2 student objects and print whether each has passed or failed.


class Student:
    def __init__(self,name,marks):
        self.name=name
        self.marks=marks
    def is_Passed(self):
        if self.marks>40:
            print("pass")
        else:
            print("fail")

s1=Student("ram",80)
print(s1.name)
print(s1.marks)
s2=Student("abc",30)
print(s2.name)
print(s2.marks)
s1.is_Passed()
s2.is_Passed()
print(s1.is_Passed())
# Out:
# ram
# 80
# abc
# 30
# pass
# fail
# pass
# None

# %%
# Q2. Create a class Employee with attributes name and company_name = "TechCorp".
# Add a class method change_company(cls, new_name) to update the company name for all employees.
# Demonstrate how this change affects all instances.

class Employee:
    company_name="TechCorp"
    def __init__(self,name):
        self.name=name
    @classmethod
    def change_company(cls,new_name):
        cls.company_name=new_name
e1=Employee("ABC")
e2=Employee("XYZ")
print(e1.company_name)
print(e2.company_name)
Employee.change_company("corp")
print(e1.company_name)
print(e2.company_name)
# Out:
# TechCorp
# TechCorp
# corp
# corp

# %%
# Q4. Create a class Car with:
# •	instance attribute mileage
# •	class attribute wheels = 4
# Add an instance method display_specs() that prints mileage and wheels.
# Then change wheels using a class method, and print again.


class Car:
    wheels=4
    def __init__(self,mileges):
        self.mileges=mileges
    def display_specs(self):
        print("mileges:",self.mileges)
        print("wheels:",Car.wheels)
    @classmethod
    def change_wheels(cls,new_wheels):
        cls.wheels=new_wheels
c1=Car(20)
c1.display_specs()
Car.change_wheels(6)
c1.display_specs()
# Out:
# mileges: 20
# wheels: 4
# mileges: 20
# wheels: 6

# %%
# Q3. Create a class MathOps with a static method is_even(num) that returns True if the number is even.
# Then call it both from the class and an instance.

class MathOps:
    @staticmethod
    def is_even(num):
        return num%2==0
m=MathOps.is_even(10)
print(m)
m1=MathOps()
print(m1.is_even(7))
# Out:
# True
# False

# %%
# Q5. Create a class Temperature with:
# •	instance attribute celsius
# •	a static method to_fahrenheit(celsius)
# •	an instance method show_conversion() that uses the static method to print both values.

class Temperature:
    def __init__(self,celsius):
        self.celsius=celsius
    @staticmethod
    def to_fahrenheit(celsius):
        return(celsius*9/5)+32
    def show_conversion(self):
        f=Temperature.to_fahrenheit(self.celsius)
        print(self.celsius)
        print(f)
t1=Temperature(25)
t1.show_conversion()
# Out:
# 25
# 77.0

# %%
# Q6. Create a class Book with:
# •	instance attributes title, author
# •	a class variable total_books
# •	a class method from_string(cls, book_str) that creates an object from "title-author" format
# •	a static method is_valid_title(title) that checks if title has at least 3 characters
# •	increment total_books for every book created
# Demonstrate:
# •	Creating books using both the constructor and the class method
# •	Validating titles before creation

class Book:
    total_books=0
    def __init__(self,title,author):
        self.title=title
        self.author=author
        Book.total_books+=1
    @classmethod
    def from_string(cls,book_str):
        title,author=book_str.split("-")
        return cls(title,author)
    @staticmethod
    def is_valid_title(title):
        if len(title)>=3:
            return True
        return False
title1="python"
author1="guido"
if Book.is_valid_title(title1):
    b1=Book(title1,author1)
    print(b1.title, "-", b1.author)
x="java-james"
title2=x.split("-")[0]
if Book.is_valid_title(title2):
    b2=Book.from_string(x)
    print(b2.title, "-", b2.author)
# Out:
# python - guido
# java - james

# %%
# Q7. Create a class Employee with:
# •	instance attributes: name, base_salary
# •	class variable: bonus_rate = 0.1
# •	instance method: final_salary() → base_salary + (base_salary × bonus_rate)
# •	class method: update_bonus(cls, new_rate) → updates bonus for all employees
# •	static method: is_valid_salary(sal) → checks if salary > 0
# Create two employees, show final salaries, update bonus rate, and show again.

class Employee:
    bonus_rate=0.1
    def __init__(self,name,base_salary):
        self.name=name
        self.base_salary=base_salary
    def final_salary(self):
        return self.base_salary+(self.base_salary*Employee.bonus_rate)
    @classmethod
    def update_bonus(cls,new_rate):
        cls.bonus_rate=new_rate
    @staticmethod
    def is_valid_salary(sal):
        if sal>0:
            return True
        else:
            return False
if Employee.is_valid_salary(5000):
    e1=Employee("ABC",5000)
    print(e1.final_salary())
if Employee.is_valid_salary(6000):
    e2=Employee("XYZ",6000)
    print(e2.final_salary())
e1.update_bonus(0.2)
print(e1.final_salary())
print(e2.final_salary())
Employee.update_bonus(0.2)
print(e1.final_salary())
print(e2.final_salary())
# Out:
# 5500.0
# 6600.0
# 6000.0
# 7200.0
# 6000.0
# 7200.0

# %%
# Q8. Create a class Course with:
# •	class variable total_students
# •	instance variable student_name
# •	instance method enroll() → increments total_students
# •	class method show_total(cls) → prints total students
# •	static method is_eligible(age) → returns True if age ≥ 18
# Demonstrate enrolling multiple students and show total count.

class Course:
    total_students=0
    def __init__(self,student_name):
        self.student_name=student_name
    def enroll(self):
        Course.total_students+=1
    @classmethod
    def show_total(cls):
        print(cls.total_students)
    @staticmethod
    def is_eligible(age):
        return age>=18
if Course.is_eligible(20):
    s1=Course("abc")
    s1.enroll()
    print(s1.student_name)
    print(s1.total_students)
    Course.show_total()
# Out:
# abc
# 1
# 1

# %%
# Q9. Create a class BankAccount with:
# •	class variable bank_name
# •	instance variables holder and balance
# •	instance method deposit(amount)
# •	class method change_bank_name(cls, new_name)
# •	static method validate_amount(amount) → returns True if amount > 0
# Show transactions and how static + class methods work together.

class BankAccount:
    bank_name="SBI"
    def __init__(self,holder,balance):
        self.holder=holder
        self.balance=balance
    def deposit(self,amount):
        if self.validate_amount(amount):
            self.balance=self.balance+amount
            print(self.holder,amount)
            print(self.balance)
    @classmethod
    def change_bank_name(cls,new_name):
        cls.bank_name=new_name
    @staticmethod
    def validate_amount(amount):
        return amount>0
a1=BankAccount("abc",1000)
print(BankAccount.bank_name)
print(a1.holder)
print(a1.balance)
a1.deposit(100)
BankAccount.change_bank_name("KOTAK")
print(BankAccount.bank_name)
# Out:
# SBI
# abc
# 1000
# abc 100
# 1100
# KOTAK

# %%
# Q10. Create a class Student with:
# •	class variable passing_marks = 40
# •	instance attributes name, marks
# •	instance method result() → prints pass/fail using class variable
# •	class method update_passing_marks(cls, new_marks)
# •	static method grade_category(marks) → returns "A", "B", "C" based on score ranges
# Use all three in a program that:
# 1.	Creates students
# 2.	Updates the passing criteria
# 3.	Displays grade category and result

class Student:
    passing_marks=40
    def __init__(self,name,marks):
        self.name=name
        self.marks=marks
    def result(self):
        if self.marks>=Student.passing_marks:
            print(self.name,"pass")
        else:
            print(self.name,"fail")
    @classmethod
    def update_passing_marks(cls,new_marks):
        cls.passing_marks=new_marks
    @staticmethod
    def grade_category(marks):
        if marks>=90 and marks<=100:
            return "A"
        elif marks>=80 and marks<=89:
            return "B"
        else:
            return "C"
s1=Student("abc",95)
print(s1.name)
print(Student.grade_category(s1.marks))
s1.result()
# Out:
# abc
# A
# abc pass

# %%
# | Method Type         | Uses                       | First Parameter    | Decorator       | Purpose                             |
# | ------------------- | -------------------------- | ------------------ | --------------- | ----------------------------------- |
# | **Instance Method** | Works with **object data** | `self`             | No decorator    | Access or modify instance variables |
# | **Class Method**    | Works with **class data**  | `cls`              | `@classmethod`  | Access or modify class variables    |
# | **Static Method**   | Independent method         | No `self` or `cls` | `@staticmethod` | Utility function related to class   |

# 1️⃣ Instance Method
# Most common method
# Works with instance (object) variables
# Uses self parameter
# Example:
# class Student:
#     def __init__(self, name):
#         self.name = name
#     def display(self):
#         print("Student Name:", self.name)
# s = Student("Chandana")
# s.display()
# ✔ display() is an instance method because it uses self.

# 2️⃣ Class Method
# Works with class variables
# Uses cls parameter
# Defined using @classmethod
# Example:
# class Student:
#     college = "ABC College"
#     @classmethod
#     def show_college(cls):
#         print("College:", cls.college)
# Student.show_college()
# ✔ show_college() is a class method because it uses cls.

# 3️⃣ Static Method
# Does not use instance or class variables
# Just a utility function inside class
# Uses @staticmethod
# Example:
# class Math:
#     @staticmethod
#     def add(a, b):
#         return a + b
# print(Math.add(5, 3))
# ✔ add() is a static method.

# ✅ Simple Way to Remember
# Instance Method → self → works with object
# Class Method → cls → works with class
# Static Method → no self/cls → independent function
