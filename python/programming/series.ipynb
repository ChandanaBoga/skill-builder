# %%
n=int(input())
c=0
for i in range(1,n+1):
    c+=1
    if c!=1:
        print(", ",end="")
    if i%2==0:
        print("Fizz",end="")
        if i%3==0:
            print("Buzz",end="")
    elif i%3==0:
        print("Buzz",end="")
    else:
        print(i,end="")
# Out:
# 1, Fizz, Buzz, Fizz

# %%
n=int(input())
while n>0:
    r=n%10
    n=n//10
    break
c=0
temp=n
while temp>0:
    r=temp%10
    c+=1
    temp=temp//10
temp=n
while temp>0:
    res=temp%(10**(c-1))
    print(res)
    break
    []
sum=0
while res>0:
    r=res%10
    sum=sum+r
    res=res//10
print(sum)
# Out:
# 243
# 9

# %%
n=int(input())
rev=0
while True:
    while n>0:
        r=n%10
        rev=rev*10+r
        n=n//10
    sum=0
    c=0
    while rev>0:
        r=rev%10
        c+=1
        sum+=r
        rev=rev//10
    if c==1:
        print(sum)
        break
    else:
        n=sum
# Out:
# 1
